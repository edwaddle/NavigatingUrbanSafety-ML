# %% [markdown]
# ### Import Libraries needed for EDA

# %%
#Import Libraries
import pandas as pd
import os
from ydata_profiling import ProfileReport

#Currently, if you run this in codespaces, it doesn't have enough RAM to generate the report. 
skip_report_generation = True

# %% [markdown]
# ### Import the data into a Pandas Dataframe

# %%
df_historical = pd.read_csv('../Data/Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv')
df_present = pd.read_csv('../Data/Police_Department_Incident_Reports__2018_to_Present.csv')

# %% [markdown]
# #### Auto Generated reports

# %%
#If eda_historical and eda_present are not in the Report folder, then run the following code

if (('eda_historical.html' and 'eda_present.html' not in os.listdir('../Report')) and skip_report_generation == False):
    profile_historical = ProfileReport(df_historical)
    profile_historical.to_file(output_file="../Report/eda_historical.html")
    profile_present = ProfileReport(df_present)
    profile_present.to_file(output_file="../Report/eda_present.html")

# %% [markdown]
# ## Historical Data

# %%
df_historical.describe()
# Out:
#                PdId    IncidntNum  Incident Code             X             Y  \
# count  2.129525e+06  2.129525e+06   2.129525e+06  2.129525e+06  2.129525e+06
# mean   1.042410e+13  1.042410e+08   2.753279e+04 -1.224228e+02  3.777135e+01
# std    4.617922e+12  4.617922e+07   2.598539e+04  2.979630e-02  4.256712e-01
# min    3.979630e+08  3.979000e+03   0.000000e+00 -1.225136e+02  3.770788e+01
# 25%    6.125908e+12  6.125908e+07   6.244000e+03 -1.224330e+02  3.775388e+01
# 50%    1.011933e+13  1.011933e+08   1.520100e+04 -1.224166e+02  3.777542e+01
# 75%    1.409596e+13  1.409596e+08   6.301000e+04 -1.224070e+02  3.778466e+01
# max    9.915824e+13  9.915824e+08   7.503000e+04 -1.205000e+02  9.000000e+01
#
#        SF Find Neighborhoods 2 2  Current Police Districts 2 2  \
# count               2.123558e+06                  2.128444e+06
# mean                5.191933e+01                  4.853053e+00
# std                 3.162770e+01                  2.765017e+00
# ...

# %%
df_historical.isnull().sum()
# Out:
# PdId                                                              0
# IncidntNum                                                        0
# Incident Code                                                     0
# Category                                                          0
# Descript                                                          0
# DayOfWeek                                                         0
# Date                                                              0
# Time                                                              0
# PdDistrict                                                        1
# Resolution                                                        0
# Address                                                           0
# X                                                                 0
# Y                                                                 0
# location                                                          0
# ...
